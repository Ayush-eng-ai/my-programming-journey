# %% [markdown]
# #OPPE_2 / Set_1
#
# ---
# #Question: 1
# ---
# ###Sum of squares and absolute difference of squares
# Write a function sum_squares_abs_diff_squares that takes two integer inputs, a and b, and returns a tuple with:
#
#     1. The sum of the squares of a and b.
#
#     2. The absolute difference of the squares of a and b.
#
# NOTE: This is a function type question, you don't have to take input or print the output, just have to complete the required function definition.
#
# Example
# Given the inputs a = 3 and b = 4:
#
# Explanation
#
#     • The sum of squares would be 9 + 16 = 25.
#
#     • The absolute difference of squares would be |9 - 16| = 7.
#
# So, sum_squares_abs_diff_squares(3, 4) should return (25, 7).
#
# *** starting code above this question
# ![image.png](data:image/png;base64,...)

# %%
def sum_squares_abs_diff_squares(a, b):
    # Calculate the square of a and b
    square_a = a * a
    square_b = b * b

    # Calculate the sum of squares
    sum_of_squares = square_a + square_b

    # Calculate the absolute difference of squares
    abs_diff_of_squares = abs(square_a - square_b)

    # Return a tuple with both results
    return (sum_of_squares, abs_diff_of_squares)

# Example usage (for testing, not part of the required function):
# result = sum_squares_abs_diff_squares(3, 4)
# print(result) # Expected output: (25, 7)

# %% [markdown]
# #Question: 2
# ---
# ###Is Odd-Length Palindrome
# Write a function is_odd_length_palindrome that takes a string s and returns True if s is a palindrome of odd length, and False otherwise.
#
# ####NOTE:
# This is a function type question, you don't have to take input or print the output, just have to complete the required function definition.
#
# Example
#
#     • "hello" --> False (not a palindrome)
#
#     • "noon" --> False (palindrome but not odd length)
#
#     • "nun" --> True (palindrome and odd length)
#
# ***starting code of image
# ![image.png](data:image/png;base64,...)

# %%
def is_odd_length_palindrome(s):
    # Check if the string is a palindrome
    is_palindrome = (s == s[::-1])

    # Check if the length of the string is odd
    is_odd_length = (len(s) % 2 != 0)

    # Return True only if both conditions are met
    return is_palindrome and is_odd_length

# Example usage (for testing, not part of the required function):
# print(is_odd_length_palindrome("hello")) # Expected: False
# print(is_odd_length_palindrome("noon"))  # Expected: False
# print(is_odd_length_palindrome("nun"))   # Expected: True
# print(is_odd_length_palindrome("madam"))  # Expected: True
# print(is_odd_length_palindrome("a"))     # Expected: True

# %% [markdown]
# #Question: 3
# ---
# ###Remove elements at given two indices of a list
# Write a function remove_elements_at_two_indices that takes a list l and two indices i1 and i2. The function should remove the elements at these two indices from the list l.
#
# Assume the indices are non-negative and unique.
#
# The function should not return anything but should modify the input list directly.
#
# ####NOTE:
# This is a function type question, you don't have to take input or print the output, just have to complete the required function definition.
#
# ####Example
#
# * l = [1, 2, 3, 4, 5, 6, 7]
# * i1 = 5
# * i2 = 1
# *  remove_elements_at_two_indices(l, i1, i2)
# *  l
# [1, 3, 4, 5, 7]
# ###Explanation
# The elements at indices 5 and 1 are 6 and 2, respectively. These elements are removed from the list l.
# ---
# ***Starting code of image
# ![image.png](data:image/png;base64,...)

# %%
def remove_elements_at_two_indices(l, i1, i2):
    # Ensure the indices are processed in descending order to prevent index shifting issues
    # if i1 was smaller than i2 and removed first.
    if i1 > i2:
        l.pop(i1)
        l.pop(i2)
    else:
        l.pop(i2)
        l.pop(i1)

# Example usage (for testing, not part of the required function):
# l1 = [1, 2, 3, 4, 5, 6, 7]
# i1_1 = 5
# i2_1 = 1
# remove_elements_at_two_indices(l1, i1_1, i2_1)
# print(l1) # Expected output: [1, 3, 4, 5, 7]

# l2 = [10, 20, 30, 40, 50]
# i1_2 = 0
# i2_2 = 3
# remove_elements_at_two_indices(l2, i1_2, i2_2)
# print(l2) # Expected output: [20, 30, 50]

# %% [markdown]
# #Question:4
# ---
# ###Sum of Squares of Even Numbers
# Write a function sum_of_squares_of_even that takes a list of integers nums and returns the sum of squares of all even numbers in the list.
#
# *  nums = [1, 2, 3, 4, 5, 6]
# *  sum_of_squares_of_even(nums)
# 56
# ####NOTE:
# This is a function type question, you don't have to take input or print the output, just have to complete the required function definition.
#
# ####Explanation
# In the list [1, 2, 3, 4, 5, 6], the even numbers are 2, 4, and 6. The sum of their squares is 4 + 16 + 36 = 56.
#
# ---
# ***starting code of image
# ![image.png](data:image/png;base64,...)

# %%
def sum_of_squares_of_even(nums):
    total_sum_of_squares = 0
    for num in nums:
        if num % 2 == 0:
            total_sum_of_squares += num * num
    return total_sum_of_squares

# Example usage (for testing, not part of the required function):
# nums1 = [1, 2, 3, 4, 5, 6]
# print(sum_of_squares_of_even(nums1)) # Expected: 56

# nums2 = [10, 15, 20]
# print(sum_of_squares_of_even(nums2)) # Expected: 100 + 400 = 500

# %% [markdown]
# #Questionz: 5
# ---
# ###Upper Case Only Vowels
# Write a program that takes a passage with n lines of text as input. For each line, convert all vowels (a, e, i, o, u) to uppercase and all other characters to lowercase.
#
# ####NOTE:
# This is an I/O type question, you need to write the whole code for taking input and printing the output.
#
# Input Format
#
#     • The first line contains an integer n, the number of lines.
#
#     • The next n lines contain the passage.
#
# Output Format
#
#     • Print the passage with vowels in uppercase and all other characters in lowercase.
#
# ####Hint
# Use the upper and lower methods of str to convert characters as needed.
#
# ####Example
#
#
#
# ####Input:
#
# * 2
# * Hello World
# * Python Programming
# ###Output:
#
# * hEllO wOrld
# * pythOn prOgrAmmIng
# ###NOTE:
#
# You can use the below tools for working out and debugging. Click to open them in new tab.
# ---
# ***starting code of image
# ![image.png](data:image/png;base64,...)

# %%
def upper_case_only_vowels():
    try:
        n = int(input())
    except ValueError:
        print("Error: The number of lines (n) must be an integer. Please provide a valid integer input.")
        return # Exit the function if n is not a valid integer.

    vowels = "aeiouAEIOU"

    for _ in range(n):
        line = input()
        modified_line = []
        for char in line:
            if char in vowels:
                modified_line.append(char.upper())
            else:
                modified_line.append(char.lower())
        print("".join(modified_line))

# Call the function to execute the program based on the I/O type question
upper_case_only_vowels()
# Out:
# 2
# Hello World
# hEllO wOrld
# Python Programming
# pythOn prOgrAmmIng

# %% [markdown]
# #Question: 6
# ---
# ###Student Marks Filter
# Given the data of student marks in the format of list of tuples of format (rollno:str, marks:int), write a function to filter student roll numbers based on the following criteria:
#
#     • 'above_average': Students with marks above or equal to the average.
#
#     • 'below_average': Students with marks below the average.
#
#     • 'fail': Students with marks less than 40.
#
#     • 'toppers': Students with marks 90 or above.
#
#     • None: Return all roll numbers.
#
#     • Any other value should return None.
#
# The order of the roll numbers in the filtered roll numbers should be same as they appear in the data.
#
# ####NOTE:
# This is a function type question, you don't have to take input or print the output, just have to complete the required function definition. You can define helper functions if needed, but the actual solution should be in the given function template.
#
# ###Example
#
# * data = [("101", 85), ("102", 75), ("103", 45), ("104", 95), ("105", 35)]
# * print(get_roll_nos(data, 'above_average'))  # Output: ["101", "102", "104"]
# * print(get_roll_nos(data, 'fail'))           # Output: ["105"]
# * print(get_roll_nos(data, 'toppers'))         # Output: ["104"]
# * print(get_roll_nos(data))                   # Output: ["101", "102", "103", "104", "105"]
# ---
# ***![image.png](data:image/png;base64,...)

# %%
def get_roll_nos(data, filter_type=None):
    if not data:
        return []

    marks = [mark for rollno, mark in data]
    total_marks = sum(marks)
    num_students = len(marks)
    average_marks = total_marks / num_students

    filtered_roll_numbers = []

    if filter_type == 'above_average':
        for rollno, mark in data:
            if mark >= average_marks:
                filtered_roll_numbers.append(rollno)
    elif filter_type == 'below_average':
        for rollno, mark in data:
            if mark < average_marks:
                filtered_roll_numbers.append(rollno)
    elif filter_type == 'fail':
        for rollno, mark in data:
            if mark < 40:
                filtered_roll_numbers.append(rollno)
    elif filter_type == 'toppers':
        for rollno, mark in data:
            if mark >= 90:
                filtered_roll_numbers.append(rollno)
    elif filter_type is None:
        for rollno, mark in data:
            filtered_roll_numbers.append(rollno)
    else:
        return None # Any other value for filter_type returns None

    return filtered_roll_numbers

# Example usage (for testing, not part of the required function):
data = [("101", 85), ("102", 75), ("103", 45), ("104", 95), ("105", 35)]
print(get_roll_nos(data, 'above_average'))
print(get_roll_nos(data, 'below_average'))
print(get_roll_nos(data, 'fail'))
print(get_roll_nos(data, 'toppers'))
print(get_roll_nos(data))
print(get_roll_nos(data, 'invalid_filter'))
# Out:
# ['101', '102', '104']
# ['103', '105']
# ['105']
# ['104']
# ['101', '102', '103', '104', '105']
# None

# %% [markdown]
# #Question: 7
# ---
# ###Print Pattern - V
# Given an integer n (where n > 0), print a "V" shaped pattern with n rows. The pattern should use backslashes (\) and forward slashes (/) for each row, with the v character at the bottom. There should be no spaces to the right of the pattern.
#
# ####NOTE:
# This is an I/O type question, you need to write the whole code for taking input and printing the output.
#
# Input Format
#
#     • A single integer n, representing the number of rows in the pattern.
#
# Output Format
#
#     • A "V" shaped pattern with n rows, as described.
#
# Constraints
#
#     • 1 <= n
#
# ####Examples
#
# *** Input:***
#
# 1
# * Output:
#
# * v
# * Input:
#
# 2
# * Output:
#
# * \ /
#  * v
# * Input:
#
# 3
# * Output:
#
# * \   /
# *  \ /
# *   v
# ####NOTE:
# You can use the below tools for working out and debugging. Click to open them in new tab.
# ---
# ***starting code of image

# %%
# Define the function to print the 'V' shaped pattern
def print_v_pattern():
    # Take integer input for n, the number of rows
    n = int(input())

    # Iterate from 0 to n-2 to print the lines with backslashes and forward slashes
    for i in range(n - 1):
        # Calculate the number of leading spaces
        leading_spaces = ' ' * i
        # Calculate the number of spaces between the backslash and forward slash
        # For n=1, there are 0 middle spaces. For n=2, 1 middle space. For n=3, 3 middle spaces for first row, 1 for second.
        # This formula calculates (n - 1 - i) * 2 - 1 spaces for a given row i.
        # The total width of the 'V' increases by 2 characters per row (one on each side) as we go up.
        # So, the number of internal spaces decreases by 2 per row as we go down towards 'v'.
        # At row i (0-indexed), there are (n - 1 - i) pairs of leading/trailing spaces for the 'V' arms.
        # The innermost part (just above 'v') has 1 space for n=2, 1 space for n=3 (second row).
        # The formula (n - 1 - i) * 2 - 1 ensures this correct spacing.
        middle_spaces = ' ' * ((n - 1 - i) * 2 - 1)

        # Print the current row
        print(f"{leading_spaces}\\{middle_spaces}/")

    # Print the last row, which contains the 'v' character
    # It should be indented by (n-1) spaces
    last_row_indentation = ' ' * (n - 1)
    print(f"{last_row_indentation}v")

# Call the function to execute the program based on the I/O type question
print_v_pattern()
# Out:
# 9
# \               /
#  \             /
#   \           /
#    \         /
#     \       /
#      \     /
#       \   /
#        \ /
#         v

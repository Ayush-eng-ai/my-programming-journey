# %% [markdown]
# #Useful Resources for Data Analysis
# ---
# ---
# | Level        | Module / Library / Framework | Type           | Main Use             | What You Can Do                        |
# | ------------ | ---------------------------- | -------------- | -------------------- | -------------------------------------- |
# | Beginner     | csv                          | Module         | CSV Data Handling    | read csv, write csv, reports           |
# | Beginner     | json                         | Module         | JSON Data            | API data read, convert dict/json       |
# | Beginner     | math                         | Module         | Calculations         | statistics basics, formulas            |
# | Beginner     | statistics                   | Module         | Basic Statistics     | mean, median, mode, stdev              |
# | Beginner     | pandas                       | Library        | Data Analysis        | table data clean, filter, sort         |
# | Beginner     | matplotlib                   | Library        | Visualization        | line chart, bar chart, pie chart       |
# | Beginner     | openpyxl                     | Library        | Excel Files          | read/write Excel files                 |
# | Intermediate | numpy                        | Library        | Numerical Computing  | arrays, matrix, fast calculations      |
# | Intermediate | seaborn                      | Library        | Advanced Charts      | heatmap, pairplot, styled graphs       |
# | Intermediate | scipy                        | Library        | Scientific Analysis  | stats tests, optimization              |
# | Intermediate | plotly                       | Library        | Interactive Charts   | zoom charts, dashboards                |
# | Intermediate | sqlalchemy                   | Library        | Database Analysis    | SQL connect, query data                |
# | Intermediate | sqlite3                      | Module         | Database             | local database analysis                |
# | Intermediate | jupyter                      | Framework/Tool | Analysis Notebook    | run code step by step                  |
# | Advanced     | scikit-learn                 | Library        | Machine Learning     | prediction, clustering, classification |
# | Advanced     | statsmodels                  | Library        | Statistical Modeling | regression, hypothesis testing         |
# | Advanced     | xgboost                      | Library        | Boosting Models      | high accuracy ML models                |
# | Advanced     | pyspark                      | Framework      | Big Data Analysis    | huge datasets process                  |
# | Advanced     | dask                         | Framework      | Parallel Data        | large pandas-like analysis             |
# | Advanced     | tensorflow                   | Library        | Deep Learning        | AI models, neural networks             |
# | Advanced     | streamlit                    | Framework      | Data Apps            | dashboards, ML web apps                |
# | Advanced     | dash                         | Framework      | Business Dashboard   | live analytics dashboards              |

# %% [markdown]
# #Learning Path
# ---
# | Stage        | Learn First                              |
# | ------------ | ---------------------------------------- |
# | Beginner     | csv, json, pandas, matplotlib            |
# | Intermediate | numpy, seaborn, scipy, SQL               |
# | Advanced     | sklearn, statsmodels, pyspark, streamlit |

# %% [markdown]
# #Best Combo for Job Ready Data Analyst
# ---
# | Purpose   | Best Tools                    |
# | ------------- | ----------------------------- |
# | Cleaning  | pandas                        |
# | Excel     | openpyxl                      |
# | Charts    | matplotlib + seaborn + plotly |
# | Stats     | scipy + statsmodels           |
# | ML        | scikit-learn                  |
# | Dashboard | streamlit / dash              |
# | Big Data  | pyspark                       |

# %% [markdown]
# #One Line Truth
#
# ###Data Analysis ka king = pandas
# ###Math speed king = numpy
# ###Charts king = seaborn / plotly
# ###Dashboard king = streamlit

# %%
Ayush_Portfolio/
│
├── 01_College_Projects/
│   ├── First_Year/
│   │   ├── Project_01_Sales_Analysis/
│   │   ├── Project_02_Student_Data/
│   │   └── Project_03_Excel_Dashboard/
│   │
│   ├── Second_Year/
│   ├── Third_Year/
│   └── Final_Year/
│
├── 02_Python_Practice/
│   ├── Basics/
│   ├── OOP/
│   ├── File_Handling/
│   ├── DSA/
│   ├── Mini_Projects/
│   └── Automation/
│
├── 03_Data_Analytics/
│   ├── Excel/
│   ├── SQL/
│   ├── PowerBI/
│   ├── Tableau/
│   ├── Pandas/
│   ├── NumPy/
│   └── Statistics/
│
├── 04_Portfolio_Projects/
│   ├── Sales_Dashboard/
│   ├── HR_Analytics/
│   ├── IPL_Data_Analysis/
│   ├── Customer_Churn/
│   └── Finance_Report/
│
├── 05_Resume_Certificates/
│   ├── Resume/
│   ├── Certificates/
│   ├── Internship_Letters/
│   └── Achievements/
│
├── 06_GitHub_Upload/
│   ├── Ready_Projects/
│   └── README_Files/
│
├── 07_Job_Preparation/
│   ├── Aptitude/
│   ├── Interview_Questions/
│   ├── HR_Questions/
│   ├── SQL_Interview/
│   └── Python_Interview/
│
├── 08_Notes/
│   ├── Python_Notes/
│   ├── SQL_Notes/
│   ├── Statistics_Notes/
│   └── Data_Analytics_Notes/
│
└── 09_Personal_Brand/
    ├── LinkedIn_Content/
    ├── Portfolio_Website/
    └── Bio_About_Me/

# %%
college_projects/
│
├── First_Year/
│   ├── Project_01_Sales_Analysis/
│   ├── Project_02_Student_Data/
│   └── Project_03/
│
├── Second_Year/
│   ├── Project_01/
│   └── ...
│
├── Third_Year/
├── Final_Year/
│
└── README.md

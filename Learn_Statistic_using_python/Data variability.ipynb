# %%
#Lets find range of a data 
df = np.array([10, 20, 30, 40, 50])

np.ptp(df)
# Out:
# np.int64(40)

# %% [markdown]
# Range
# IQT( Inter Quartile range )
# Finding the Outlieris

# %%
# %pip install matplotlib

import numpy as np
import matplotlib  as plt
import seaborn as sns
